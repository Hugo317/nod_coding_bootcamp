# %% [markdown]
# ## Index Objects

# %%
import pandas as pd

# %%
df = pd.read_csv("listings.csv")

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4806, step=1)

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 4803, 4804, 4805], shape=(4806,))

# %%
df.sort_values(by="price", ascending=False, inplace=True) ##INPLACE MAKES A CHANGE PERMANENT ON THE LIST

# %%
df
# Out:
#                        id                                              name  \
# 2340   920900355178934780                  VYN 2.0 - Penthouse Suite Deluxe
# 4301  1617201210178577353                                       Grand House
# 1565             54126655  Small privately owned hotel 12 rooms and 22 beds
# 1641   599723488406885421                                Hyr hela Hotellet!
# 1914   749651285872917342                            VYN 3.0 - Suite Deluxe
# ...                   ...                                               ...
# 4644  1695556047556384252               Apartment with balcony in Söderort.
# 4718  1706432630118526116        Beautiful Vasastan Apartment by Vasaparken
# 4738  1708925436755392273                           Stockholm minilägenhet,
# 4780  1714692619859001686    Bright Stockholm family apartment by the park.
# 4801  1717861167246979973                  Mysig lägenhet nära till naturen
#
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                        id                                              name  \
# 0      920900355178934780                  VYN 2.0 - Penthouse Suite Deluxe
# 1     1617201210178577353                                       Grand House
# 2                54126655  Small privately owned hotel 12 rooms and 22 beds
# 3      599723488406885421                                Hyr hela Hotellet!
# 4      749651285872917342                            VYN 3.0 - Suite Deluxe
# ...                   ...                                               ...
# 4801  1695556047556384252               Apartment with balcony in Söderort.
# 4802  1706432630118526116        Beautiful Vasastan Apartment by Vasaparken
# 4803  1708925436755392273                           Stockholm minilägenhet,
# 4804  1714692619859001686    Bright Stockholm family apartment by the park.
# 4805  1717861167246979973                  Mysig lägenhet nära till naturen
#
# ...

# %% [markdown]
# ## `loc[]`and `ioc[]``

# %%
#LETS US LOCAT A ROW BASED ON A LABEL OR INT
#loc[] locat wiht label
#iloc[] int index position

df.loc[0]
# Out:
# id                                              920900355178934780
# name                              VYN 2.0 - Penthouse Suite Deluxe
# host_id                                                  361529221
# host_profile_id                                1469725475544260882
# host_name                                                   Martin
# neighbourhood_group                                            NaN
# neighbourhood                                           Östermalms
# latitude                                                  59.33292
# longitude                                                 18.08144
# room_type                                          Entire home/apt
# price                                                      40000.0
# minimum_nights                                                   7
# number_of_reviews                                                0
# last_review                                                    NaN
# ...

# %%
df.iloc[0]
# Out:
# id                                              920900355178934780
# name                              VYN 2.0 - Penthouse Suite Deluxe
# host_id                                                  361529221
# host_profile_id                                1469725475544260882
# host_name                                                   Martin
# neighbourhood_group                                            NaN
# neighbourhood                                           Östermalms
# latitude                                                  59.33292
# longitude                                                 18.08144
# room_type                                          Entire home/apt
# price                                                      40000.0
# minimum_nights                                                   7
# number_of_reviews                                                0
# last_review                                                    NaN
# ...

# %%
df.loc[:4] #inclusive on the end
# Out:
#                     id                                              name  \
# 0   920900355178934780                  VYN 2.0 - Penthouse Suite Deluxe
# 1  1617201210178577353                                       Grand House
# 2             54126655  Small privately owned hotel 12 rooms and 22 beds
# 3   599723488406885421                                Hyr hela Hotellet!
# 4   749651285872917342                            VYN 3.0 - Suite Deluxe
#
#      host_id      host_profile_id    host_name  neighbourhood_group  \
# 0  361529221  1469725475544260882       Martin                  NaN
# 1  361529221  1469725475544260882       Martin                  NaN
# 2  280607063  1469475819689082766  Hotel Söder                  NaN
# 3  280607063  1469475819689082766  Hotel Söder                  NaN
# 4  361529221  1469725475544260882       Martin                  NaN
#
#   neighbourhood   latitude  longitude        room_type    price  \
# ...

# %%
df.iloc[:5] #exclusive on the end

# %%
df.loc[:99, ["name","price"]]
# Out:
#                                                  name    price
# 0                    VYN 2.0 - Penthouse Suite Deluxe  40000.0
# 1                                         Grand House  30000.0
# 2    Small privately owned hotel 12 rooms and 22 beds  25998.0
# 3                                  Hyr hela Hotellet!  25995.0
# 4                              VYN 3.0 - Suite Deluxe  25714.0
# ..                                                ...      ...
# 95                                   Stjärnhovsvillan   6544.0
# 96         Upscale cityvilla with pool, gym and sauna   6461.0
# 97             Elegant apartment in historic Old Town   6454.0
# 98  Spacious house with panoramic view of Lake Mäl...   6444.0
# 99           Exklusiv våning i city – plats för många   6442.0
#
# [100 rows x 2 columns]

# %%
df.iloc[:99,[3,9]]
# Out:
#         host_profile_id        room_type
# 0   1469725475544260882  Entire home/apt
# 1   1469725475544260882  Entire home/apt
# 2   1469475819689082766     Private room
# 3   1469475819689082766  Entire home/apt
# 4   1469725475544260882  Entire home/apt
# ..                  ...              ...
# 94  1462925813574055812  Entire home/apt
# 95  1467091193440502924  Entire home/apt
# 96  1466692029137378713  Entire home/apt
# 97  1470327415919950283  Entire home/apt
# 98  1462918119226921136  Entire home/apt
#
# [99 rows x 2 columns]

# %%
df.set_index("host_id").index
# Out:
#                             id  \
# host_id
# 361529221   920900355178934780
# 361529221  1617201210178577353
# 280607063             54126655
# 280607063   599723488406885421
# 361529221   749651285872917342
# ...                        ...
# 257610489  1695556047556384252
# 506295261  1706432630118526116
# 118686164  1708925436755392273
# 72727478   1714692619859001686
# 25450276   1717861167246979973
#
#                                                        name  \
# host_id
# 361529221                  VYN 2.0 - Penthouse Suite Deluxe
# 361529221                                       Grand House
# 280607063  Small privately owned hotel 12 rooms and 22 beds
# 280607063                                Hyr hela Hotellet!
# 361529221                            VYN 3.0 - Suite Deluxe
# ...                                                     ...
# 257610489               Apartment with balcony in Söderort.
# 506295261        Beautiful Vasastan Apartment by Vasaparken
# ...

# %% [markdown]
# ## GROUP BY IN `pandas`

# %% [markdown]
# #agg function in pandas

# %%
df["price"].mean()
# Out:
# np.float64(2388.1994485294117)

# %%
df.price.sum()
# Out:
# np.float64(7795083.0)

# %%
df[["neighbourhood","price"]].groupby("neighbourhood").mean().sort_values(by="price",ascending=False).plot(kind="bar")
# Out:
# <Axes: xlabel='neighbourhood'>
