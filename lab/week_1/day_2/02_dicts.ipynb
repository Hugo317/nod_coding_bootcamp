# %% [markdown]
# <img src="https://iili.io/2FquTQ4.png" alt="2FquTQ4.png" border="0" width="150" />

# %% [markdown]
# # Dictionaries Lab

# %% [markdown]
# # 1. Countries & Capitals
#
# Create a dictionary with the three countries below as the keys and their  capital as the values:
#
# - Argentina
#
# - India
#
# - Japan

# %%
country_and_capital = dict(Argentina="Buenos Aires", India="MuNew Dehli", Japan="Tokyo")
print(country_and_capital)
# Out:
# {'Argentina': 'Buenos Aires', 'India': 'MuNew Dehli', 'Japan': 'Tokyo'}

# %% [markdown]
# ## 1.1 Update the dictionary
#
# Update the dictionary with:
#
# - Cuba
# - Israel
# - Kazakhstan
#
# (with the capitals as values)

# %%
country_and_capital.update({"Cuba": "Havana", "Israel": "Jerusalem", "Kazakhstan": "Astana"})
print(country_and_capital)
# Out:
# {'Argentina': 'Buenos Aires', 'India': 'MuNew Dehli', 'Japan': 'Tokyo', 'Cuba': 'Havana', 'Israel': 'Jerusalem', 'Kazakhstan': 'Astana'}

# %% [markdown]
# ## 1.2 How many elements are there in your dictionary?

# %%
len(country_and_capital.keys())
# Out:
# 6

# %% [markdown]
# ## 1.3 Query your dictionary so it returns the capital for Argentina

# %%
country_and_capital.get("Argentina")
# Out:
# 'Buenos Aires'

# %% [markdown]
# # 2. Data structures as values
#
# The values in a dictionary can be of any data type or of any data structure. Below you will find an example with lists as values
#
# - First query the dictionary to access the list with the 4 different data types
# - Then query the dictionary to retrieve only the "tuple" element

# %%
dct = {
    "data types": [str, int, float, bool],
    "data structures": [list, dict, tuple, set]
}

# %%
dictionarie = dct
a_list = dct.get("data types")
a_class = dct.get("data types")[1]
a_tuple = dct.items()
print(dictionarie)
print(a_list)
print(a_class)
print(a_tuple)
# Out:
# {'data types': [<class 'str'>, <class 'int'>, <class 'float'>, <class 'bool'>], 'data structures': [<class 'list'>, <class 'dict'>, <class 'tuple'>, <class 'set'>]}
# dict_keys(['data types', 'data structures'])
# [<class 'str'>, <class 'int'>, <class 'float'>, <class 'bool'>]
# <class 'int'>
# dict_items([('data types', [<class 'str'>, <class 'int'>, <class 'float'>, <class 'bool'>]), ('data structures', [<class 'list'>, <class 'dict'>, <class 'tuple'>, <class 'set'>])])

# %% [markdown]
# # 3. Nested Dictionaries
#
# Run the cell below to create the `sweden_info` variable. Then move on to the next question

# %%
sweden_info = {"Sweden": 
      {
          "Capital": "Stockholm", 
          "Population": 10402070,
          "GDP (Billion $)": 563.882}
      }

# %% [markdown]
# ## 3.1 Query the `sweden_info` dictionary for the population size

# %%
print(sweden_info["Sweden"]["Population"])
# Out:
# 10402070

# %% [markdown]
# ## 3.2 What is the GDP per Capita for sweden?

# %%
print(sweden_info["Sweden"]["GDP (Billion $)"])
print(type(sweden_info["Sweden"]))
# Out:
# 563.882
# <class 'dict'>

# %% [markdown]
# # 3. `countries_info`
#
# Build out the `countries_info` dictionary to include capital, population & GDP for:
#
# - China
# - India
# - USA
#
# You can find the information on Wikipedia
#
# Then move on to the next question

# %%
countries_info = {"Sweden": 
      {
          "Capital": "Stockholm", 
          "Population": 10402070,
          "GDP (Billion $)": 563.882},
      "China": 
      {
          "Capital": "Beijing", 
          "Population": 1410000000,
          "GDP (Billion $)": 19900},
      "India": 
      {
          "Capital": "Neh Dehli", 
          "Population": 1460000000,
          "GDP (Billion $)": 4000},
      "USA": 
      {
          "Capital": "Washinton D.C.", 
          "Population": 347000000,
          "GDP (Billion $)": 30800}
      }
print(countries_info)
# Out:
# {'Sweden': {'Capital': 'Stockholm', 'Population': 10402070, 'GDP (Billion $)': 563.882}, 'China': {'Capital': 'Beijing', 'Population': 1410000000, 'GDP (Billion $)': 19900}, 'India': {'Capital': 'Neh Dehli', 'Population': 1460000000, 'GDP (Billion $)': 4000}, 'USA': {'Capital': 'Washinton D.C.', 'Population': 347000000, 'GDP (Billion $)': 30800}}

# %% [markdown]
# ## 3.1 Query `countries_info` for the capital of India

# %%
type(countries_info)
type(countries_info["Sweden"])
# Out:
# dict

# %%
print(countries_info["India"]["Capital"])
# Out:
# Neh Dehli

# %% [markdown]
# ## 3.2 Calculate ratio between min & max GDP per capita
#
# - Calculate GDP per capita for all countries
#
# - Then calculate the ratio between the countries with the highest & lowest GDP per capita

# %%
GPD_and_ratio = []
for i in countries_info:
    GPD_and_ratio.append((i,((countries_info[i]["GDP (Billion $)"] * 1e09) / countries_info[i]["Population"])))

print(GPD_and_ratio)
# Out:
# [('Sweden', 54208.63347391433), ('China', 14113.475177304965), ('India', 2739.72602739726), ('USA', 88760.80691642652)]

# %% [markdown]
# # Lab finished, good job.
#
# ___

# %% [markdown]
# # Bonus Challenges!

# %% [markdown]
# # 1. `sweden_religion`
#
# Run the cell below to create the `sweden_religion` variable. Then move on to the next question

# %%
sweden_religion = {"Sweden": 
                   {
                       "Christianity": 0.67,
                       "No religion": 0.2,
                       "Islam": 0.05
                   }
                  }

# %% [markdown]
# ## 1.1 How many christians are there in Sweden?
#
# Combine information from sweden_religion & countries_info to answer this question!

# %%
nr_christians_in_sweden = countries_info["Sweden"]["Population"] * sweden_religion["Sweden"]["Christianity"]
print(nr_christians_in_sweden)
# Out:
# 6969386.9

# %% [markdown]
# # 2. `countries_religion`
#
# Build out the countries_religion dictionary to include the top 3 religions (and %) for:
#
# - China
# - India
# - USA
#
# Then move on to the next question

# %%
countries_religion = {
                  "Sweden": 
                 {
                      "Christianity": 0.67, 
                      "No religion": 0.27,
                      "Islam": 0.05
                 },
                   "China":
                 {
                      "Christianity": 0.04, 
                      "Buddhism": 0.13,
                      "No religion": 0.66},
                  "USA": 
                  {
                      "Christianity": 0.70, 
                      "No religion": .21,
                      "Non-Christian Religions": 0.07},
                  "India": 
                  {
                      "Christianity": 0.80, 
                      "Hinduism": 0.13,
                      "Islam": 0.02}
                    }

print(type(countries_religion["China"].keys()))
# Out:
# <class 'dict_keys'>

# %% [markdown]
# ## 2.1 Creating the dictionary `religion_info` (challenging question)
#
# Your end goal for this question is to have a new dictionary called `religion_info` with:
#
# - The keys in the `religion_info` dictionary being all unique religions/categories from `countries_religion`
#
# - The values being the total no. of "believers" in that religion, from the four countries included in our previous dictionaries (Sweden, China, India, USA)
#
# For example:
# - If there are 5 million christians in Sweden, 100 million in the United States and 3 million in India and 0 in China
#     - Your dictionary should say: {"Christianity": 108 000 000, ...}
#
#
# **Note:** *everything should be solved using code with scalable logic*

# %%
religions_set = set()

for i in countries_religion:
    religions_set = religions_set.union(set(countries_religion[i].keys()))

#print(religions_set)
#nr_christians_in_sweden = countries_info["Sweden"]["Population"] * sweden_religion["Sweden"]["Christianity"]

tuples_list = []

for i in religions_set:
    nr_of_religion_i = 0

    for j in countries_religion:

        if i in countries_religion[j]:

            nr_of_religion_i += countries_religion[j][i] * countries_info[j]["Population"]

        else:
            continue

    tuples_list.append((i,nr_of_religion_i))

print(tuples_list)

my_new_dict = dict(tuples_list)

print(my_new_dict)
# Out:
# [('Christianity', 1474269386.9), ('Buddhism', 183300000.0), ('Hinduism', 189800000.0), ('No religion', 1006278558.9), ('Islam', 29720103.5), ('Non-Christian Religions', 24290000.000000004)]
# {'Christianity': 1474269386.9, 'Buddhism': 183300000.0, 'Hinduism': 189800000.0, 'No religion': 1006278558.9, 'Islam': 29720103.5, 'Non-Christian Religions': 24290000.000000004}
