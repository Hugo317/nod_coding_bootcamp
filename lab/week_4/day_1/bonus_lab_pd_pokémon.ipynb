# %% [markdown]
# <img align="center" src="https://iili.io/3wI8gI.png" style="height:90px" style="width:30px"/>

# %% [markdown]
# # Pokémon Challenge
#
# import pandas and read the `pokemon.csv` file

# %%
import pandas as pd
df = pd.read_csv("pokemon.csv")

# %% [markdown]
# ### Create a new column called `A/D Ratio` whose values will be equal to `Attack` divided by `Defense`
#
# For instance, if a pokemon has an Attack score of 69 and a Defense score of 69, the corresponding `A/D Ratio` is 69/69=1

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    str
#  2   Type 1      800 non-null    str
#  3   Type 2      414 non-null    str
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), str(3)
# memory usage: 75.9 KB

# %% [markdown]
# ### Identify the pokemon with the highest `A/D Ratio` and the lowest `A/D Ratio` respectively

# %%
df["A/D Ratio"] = df["Attack"] / df["Defense"]

# %%
df["A/D Ratio"]
# Out:
# 0      1.000000
# 1      0.984127
# 2      0.987952
# 3      0.813008
# 4      1.209302
#          ...
# 795    0.666667
# 796    1.454545
# 797    1.833333
# 798    2.666667
# 799    0.916667
# Name: A/D Ratio, Length: 800, dtype: float64

# %% [markdown]
# ### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`
# <br>
#
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values:
#     -  For example, if Type 1 value is `Grass` and Type 2 value is `Poison`, Combo Type will be `Grass-Poison`
#
# <br>
#
# * If `Type 1` has a value but `Type 2` does not, `Combo Type` will be the same as `Type 1`:
#     - For example, if Type 1 is `Fire` whereas Type 2 is `NaN`, Combo Type will be `Fire`

# %% [markdown]
# ### Identify the pokemons whose `A/D Ratio` are among the top 5

# %% [markdown]
# ### Combo types for top 5 pokemons
#
# For the 5 pokemons you identified in the previous question, create a list storing the unique values of their `Combo Type`

# %% [markdown]
# ### Mean scores for top `Combo Type`
#
# For each of the `Combo Type`  obtained from the previous question, calculate the mean scores of all numeric columns
#
# Which combo type from your list has the highest average A/D Ratio?

# %% [markdown]
# # Lab finished, Good job!
# ___
#
# # Bonus Question!
#
# ## Cleanup the `Name` column
#
# We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".
