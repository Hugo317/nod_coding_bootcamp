# %% [markdown]
# <img align="center" src="https://iili.io/3wI8gI.png" style="height:90px" style="width:30px"/>

# %% [markdown]
# # 01_pandas | basics
#
# `Welcome to the first pandas lab, enjoy!`
#
# **NOTE:** Not all questions will necessarily be solvable only using the code we have practiced thus far. For example, you might have to search for a Pandas method that we havn't covered in the codealong(s).

# %% [markdown]
# # Q1
# Import the `pandas` library

# %%
import pandas as pd

# %% [markdown]
# # Q2
# Import the `fifa_2018_players.csv` dataset and save the `DataFrame` in a variable with a name of your choice

# %%
df = pd.read_csv("fifa_2018_players.csv")

# %% [markdown]
# ## Q2.1
# Check the type of your variable storing the `DataFrame`

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# # Q3
# "Print"(not using the print-statement) the `DataFrame` on your screen, and inspect the data in the columns.
#
# **Below is an explanation of the columns:**
#
# - __team__: Which team does the player play for
# - __number__: Player number
# - __position__: Which position does the player play
# - __birth_date__: Player's birthdat (year-month-day)
# - __shirt_name__: Player's shirt name
# - __club__: Which club does the player for
# - __height__: height (cm)
# - __weight__: weight (kg)
# - __league__: Which league does the player
# - __age__: How old is the player
# - __name__: player's name
# - __caps__:number of caps

# %%
df
# Out:
#           team  number position  birth_date        shirt_name  \
# 0    Argentina       1       GK  1986-02-10            GUZMÁN
# 1    Argentina       2       DF  1987-03-18           MERCADO
# 2    Argentina       3       DF  1992-08-31        TAGLIAFICO
# 3    Argentina       4       DF  1986-09-20               NaN
# 4    Argentina       5       MF  1986-01-30            BIGLIA
# ..         ...     ...      ...         ...               ...
# 731    Uruguay      19       DF  1990-10-07         S. COATES
# 732    Uruguay      20       FW  1990-03-19  J. URRETAVISCAYA
# 733    Uruguay      21       FW  1987-02-14         E. CAVANI
# 734    Uruguay      22       DF  1987-04-07        M. CACERES
# 735    Uruguay      23       GK  1983-03-25          M. SILVA
#
#                        club  height  weight league        age  \
# 0               Tigres UANL     192      90    MEX  32.339726
# 1                Sevilla FC     181      81    ESP  31.241096
# ...

# %% [markdown]
# # Q4
# Inspect the first 15 rows of your DataFrame. Who is the name of the 15th (index 14) player in the dataset?

# %%
# the name of the 15th (index 14):

# %%
df[:15]
# Out:
#          team  number position  birth_date  shirt_name  \
# 0   Argentina       1       GK  1986-02-10      GUZMÁN
# 1   Argentina       2       DF  1987-03-18     MERCADO
# 2   Argentina       3       DF  1992-08-31  TAGLIAFICO
# 3   Argentina       4       DF  1986-09-20         NaN
# 4   Argentina       5       MF  1986-01-30      BIGLIA
# 5   Argentina       6       DF  1987-03-17       FAZIO
# 6   Argentina       7       MF  1988-06-29         NaN
# 7   Argentina       8       DF  1991-10-28       ACUÑA
# 8   Argentina       9       FW  1987-12-10     HIGUAÍN
# 9   Argentina      10       FW  1987-06-24       MESSI
# 10  Argentina      11       MF  1988-02-14    DI MARÍA
# 11  Argentina      12       GK  1986-10-16      ARMANI
# 12  Argentina      13       MF  1992-12-15        MEZA
# 13  Argentina      14       DF  1984-06-08  MASCHERANO
# 14  Argentina      15       MF  1993-02-15     LANZINI
#
#                       club  height  weight league        age  \
# ...

# %% [markdown]
# # Q5
# Inspect the last 10 rows of the dataset. Who is the player with index 731?

# %%
# the player's name (index 731): 
df.iloc[-15:]
# Out:
#         team  number position  birth_date        shirt_name  \
# 721  Uruguay       9       FW  1987-01-24         L. SUAREZ
# 722  Uruguay      10       FW  1994-06-01  G. DE ARRASCAETA
# 723  Uruguay      11       FW  1986-10-12         C. STUANI
# 724  Uruguay      12       GK  1989-05-29        M. CAMPAÑA
# 725  Uruguay      13       DF  1994-03-05          G. SILVA
# 726  Uruguay      14       MF  1996-02-11       L. TORREIRA
# 727  Uruguay      15       MF  1991-08-24         M. VECINO
# 728  Uruguay      16       DF  1984-06-08        M. PEREIRA
# 729  Uruguay      17       MF  1993-02-07         D. LAXALT
# 730  Uruguay      18       FW  1996-08-14          M. GOMEZ
# 731  Uruguay      19       DF  1990-10-07         S. COATES
# 732  Uruguay      20       FW  1990-03-19  J. URRETAVISCAYA
# 733  Uruguay      21       FW  1987-02-14         E. CAVANI
# 734  Uruguay      22       DF  1987-04-07        M. CACERES
# 735  Uruguay      23       GK  1983-03-25          M. SILVA
#
# ...

# %% [markdown]
# # Q6
# Change options settings so that you can "print" out the entire `DataFrame`
#
# Then change back to default settings

# %% [markdown]
# # Q7
# Get some meta-data on your `DataFrame`!
# - How many columns are there in the DataFrame?
# - In which column(s) are there missing/NaN values, and how many are there?
# - What dtypes are there in the DataFrame?

# %%
# No. of columns in df: 
df.

# Column(s) with missing values: 
    # No. of missing values: 
    
# Dtypes:
# Out:
# <bound method DataFrame.info of           team  number position  birth_date        shirt_name  \
# 0    Argentina       1       GK  1986-02-10            GUZMÁN
# 1    Argentina       2       DF  1987-03-18           MERCADO
# 2    Argentina       3       DF  1992-08-31        TAGLIAFICO
# 3    Argentina       4       DF  1986-09-20               NaN
# 4    Argentina       5       MF  1986-01-30            BIGLIA
# ..         ...     ...      ...         ...               ...
# 731    Uruguay      19       DF  1990-10-07         S. COATES
# 732    Uruguay      20       FW  1990-03-19  J. URRETAVISCAYA
# 733    Uruguay      21       FW  1987-02-14         E. CAVANI
# 734    Uruguay      22       DF  1987-04-07        M. CACERES
# 735    Uruguay      23       GK  1983-03-25          M. SILVA
#
#                        club  height  weight league        age  \
# 0               Tigres UANL     192      90    MEX  32.339726
# 1                Sevilla FC     181      81    ESP  31.241096
# ...

# %% [markdown]
# # Q8
# Get some summary statistics of the numerical columns in the `DataFrame`
#
# - How tall is the tallest player?
# - Minimum weight of players?
# - Maximum number of players?

# %%
# How tall is the tallest player?  
# Minimum weight of players?  
# Maximum number of players?

df["height"].max()
df["number"].max()
df["weight"].min()
# Out:
# np.int64(59)

# %% [markdown]
# ## Q8.1
# Get some summary statistics of the non-numerical columns in the `DataFrame`
#
# - What is the most common league in the dataset, and how many players play in the  league in the dataset?
# - How many unique clubs are in the dataset?

# %%
# Most common league & its frequency in the data set: 

df.groupby("league").size()
df["league"].unique()
# No. of unique clubs:
# Out:
# <StringArray>
# ['MEX', 'ESP', 'NED', 'ITA', 'POR', 'FRA', 'ARG', 'CHN', 'ENG', 'JPN', 'KSA',
#  'KOR', 'GER', 'SUI', 'SCO', 'TUR', 'AUS', 'BEL', 'BRA', 'UKR', 'COL', 'SWE',
#  'CRC', 'USA', 'CAN', 'CRO', 'RUS', 'AUT', 'DEN', 'EGY', 'FIN', 'GRE', 'ISL',
#  'NOR', 'BUL', 'WAL', 'IRN', 'QAT', 'MAR', 'UAE', 'NGA', 'RSA', 'ISR', 'ROU',
#  'GUA', 'CHI', 'PAN', 'SVK', 'HON', 'PER', 'POL', 'GUI', 'SRB', 'TUN', 'URU']
# Length: 55, dtype: str

# %% [markdown]
# # Q9
# - Select the column "team" with the .(dot)notation!
# - Then, select the column "team" with the "square-bracket notation"
# - What type of data structure are the columns values stored in?

# %%
df.team
# Out:
# 0      Argentina
# 1      Argentina
# 2      Argentina
# 3      Argentina
# 4      Argentina
#          ...
# 731      Uruguay
# 732      Uruguay
# 733      Uruguay
# 734      Uruguay
# 735      Uruguay
# Name: team, Length: 736, dtype: str

# %%
df["team"]
# Out:
# 0      Argentina
# 1      Argentina
# 2      Argentina
# 3      Argentina
# 4      Argentina
#          ...
# 731      Uruguay
# 732      Uruguay
# 733      Uruguay
# 734      Uruguay
# 735      Uruguay
# Name: team, Length: 736, dtype: str

# %% [markdown]
# # Q10
# Sort the values in your DataFrame by the caps column

# %%
df.sort_values("caps")
# Out:
#             team  number position  birth_date   shirt_name  \
# 198        Egypt      15       DF  1995-06-01          NaN
# 58       Belgium      13       GK  1992-06-25     CASTEELS
# 11     Argentina      12       GK  1986-10-16       ARMANI
# 678  Switzerland      12       GK  1994-06-06        MVOGO
# 252       France      23       GK  1993-02-27       AREOLA
# ..           ...     ...      ...         ...          ...
# 371       Mexico       4       DF  1979-02-13   R. MÁRQUEZ
# 385       Mexico      18       MF  1986-09-28  A. GUARDADO
# 512     Portugal       7       FW  1985-02-05      RONALDO
# 635        Spain      15       DF  1986-03-30        RAMOS
# 184        Egypt       1       GK  1973-01-15     ELHADARY
#
#                        club  height  weight league        age  \
# 198                 Zamalek     173      72    EGY  23.035616
# 58            VfL Wolfsburg     197      86    GER  25.969863
# 11           CA River Plate     189      85    ARG  31.660274
# ...

# %% [markdown]
# # Q11
# Create a new variable named `height` from the column height

# %%
height = df["height"]

# %% [markdown]
# ## Q11.1
#
# sort the values in height

# %%
height.sort_values(ascending=False)
# Out:
# 149    201
# 163    200
# 46     199
# 5      199
# 644    198
#       ...
# 404    167
# 387    166
# 455    165
# 559    165
# 689    165
# Name: height, Length: 736, dtype: int64

# %% [markdown]
# ## Q11.2
#
# Now sort the vlaues in height descendingly (from high to low)

# %%
height.sort_values(ascending=False)

# %% [markdown]
# ## Q11.3
#
# What are the three most common values in height?

# %%
height.value_counts()
# Out:
# height
# 185    53
# 186    44
# 180    44
# 183    41
# 178    41
# 187    39
# 182    37
# 189    31
# 181    31
# 184    31
# 188    30
# 190    29
# 179    28
# 173    24
# 175    22
# 176    21
# 174    20
# 191    19
# 177    19
# 192    18
# 172    17
# 170    15
# 169    13
# 194    10
# 193    10
# 195     9
# 171     8
# 196     7
# 168     6
# 197     5
# 167     4
# 165     3
# 198     2
# 199     2
# 201     1
# 200     1
# 166     1
# Name: count, dtype: int64

# %% [markdown]
# ## Q11.4
#
# How many unique values are there in height?

# %%
len(height.unique())
# Out:
# 37

# %% [markdown]
# # Q12
#
# Create a new DataFrame only including the "name", "team" and "position" columns

# %%
new_df = df[["name","team","position"]]
new_df
# Out:
#                   name         team position
# 198      Mahmoud Hamdy        Egypt       DF
# 58       Koen Casteels      Belgium       GK
# 11       Franco Armani    Argentina       GK
# 678         Yvon Mvogo  Switzerland       GK
# 252    Alphonse Areola       France       GK
# ..                 ...          ...      ...
# 385    Andrés Guardado       Mexico       MF
# 371     Rafael Márquez       Mexico       DF
# 512  Cristiano Ronaldo     Portugal       FW
# 635       Sergio Ramos        Spain       DF
# 184    Essam El-Hadary        Egypt       GK
#
# [736 rows x 3 columns]

# %% [markdown]
# # Lab finished. Well played
# # BONUS challenges

# %% [markdown]
# ## Bonus 1
# How many percent of the players play the position DF?

# %%
df["position"].value_counts(normalize=True)
# Out:
# position
# DF    0.336957
# MF    0.316576
# FW    0.216033
# GK    0.130435
# Name: proportion, dtype: float64

# %%
df

# %% [markdown]
# ## Bonus 2
# Make a plot showing the frequency of values in the position column
#
# - y axis = frequency
# - x axis = position (should be ordered based on frequency)

# %%
# code here
df["position"].value_counts(ascending=True).plot(kind="bar")
# Out:
# <Axes: xlabel='position'>

# %%
# output should look like this
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bonus 3
# What is the mean age in each team?

# %%
df[["team","age"]].groupby(by="team").mean()
# Out:
#                     age
# team
# Argentina     29.217153
# Australia     28.134842
# Belgium       27.585587
# Brazil        28.604527
# Colombia      28.064800
# Costa Rica    29.557594
# Croatia       27.903395
# Denmark       27.143776
# Egypt         28.981298
# England       26.050506
# France        26.030137
# Germany       27.139130
# Iceland       28.583443
# Iran          27.231328
# Japan         28.580226
# Mexico        29.362954
# Morocco       27.234068
# Nigeria       25.964860
# Panama        29.263609
# Peru          27.440381
# Poland        28.311376
# Portugal      28.365932
# Russia        28.838356
# Saudi Arabia  28.730435
# Senegal       27.184157
# Serbia        26.761048
# South Korea   27.786063
# Spain         28.488029
# Sweden        28.237046
# Switzerland   27.183085
# Tunisia       26.526742
# Uruguay       28.131269

# %%
df.caps.describe()
# Out:
# count    736.000000
# mean      35.328804
# std       31.932080
# min        0.000000
# 25%       10.000000
# 50%       25.000000
# 75%       52.000000
# max      158.000000
# Name: caps, dtype: float64

# %% [markdown]
# ## Bonus 4
# What is the correlation between age and caps?

# %%
df[["team","age","caps"]]
# Out:
#             team        age  caps
# 198        Egypt  23.035616     0
# 58       Belgium  25.969863     0
# 11     Argentina  31.660274     0
# 678  Switzerland  24.021918     0
# 252       France  25.293151     0
# ..           ...        ...   ...
# 385       Mexico  31.709589   145
# 371       Mexico  39.331507   145
# 512     Portugal  33.353425   150
# 635        Spain  32.208219   152
# 184        Egypt  45.410959   158
#
# [736 rows x 3 columns]

# %%
df[["age","caps"]].corr()
# Out:
#            age      caps
# age   1.000000  0.604073
# caps  0.604073  1.000000

# %% [markdown]
# ## Bonus 5
# Which team with the lowest correlation between age and caps?
